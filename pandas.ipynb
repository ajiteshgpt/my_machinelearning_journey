# %% [markdown]
# ###pandas intoduction

# %% [markdown]
# Pandas  is a fast powerful flexible and easy to use open source data analysis and manipulation tool built on top of the python programming language
#
# Panda series; a panda series is like a column in a table it is a 1D array holding data of type any type

# %% [markdown]
# ###importing pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###series from list

# %%
#string
country=['india','pakistan','usa','nepal',]
pd.Series(country)
#pandas string ko he hamesha object samajta hai 99% of time .. agar dtype object hai to maan lena string he hoga
#index aapne aap genrete hojata hai
# Out:
# 0       india
# 1    pakistan
# 2         usa
# 3       nepal
# dtype: object

# %%
#integers
runs=[13,24,56,78,100]
pd.Series(runs)
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
#custom index
marks=[55,77,88,99,100]
subject=['hindi','english','maths','sst', 'science']
pd.Series(marks,index=subject)
# Out:
# hindi       55
# english     77
# maths       88
# sst         99
# science    100
# dtype: int64

# %%
#setting a name
marks=pd.Series(marks,index=subject,name='gupta saab ke number')
marks
# Out:
# hindi       55
# english     77
# maths       88
# sst         99
# science    100
# Name: gupta saab ke number, dtype: int64

# %% [markdown]
# ### series from dictionary

# %%
marks={'english':67,'hindi':77,'maths':55,'sst':88,'science':99}
pd.Series(marks,name='pape the number')
# Out:
# english    67
# hindi      77
# maths      55
# sst        88
# science    99
# Name: pape the number, dtype: int64

# %% [markdown]
# ###series attribute

# %%
marks=[33,44,55,66,77,66]
marks_series=pd.Series(marks,name='duniya ka papa')

# %%
#size
marks_series.size
# Out:
# 6

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'duniya ka papa'

# %%
#is unique

marks_series.is_unique
# Out:
# False

# %%
marks={'english':67,'hindi':77,'maths':55,'sst':88,'science':99}
marks_series=pd.Series(marks,name='pape the number')

#index
marks_series.index
#value
marks_series.values
# Out:
# array([67, 77, 55, 88, 99])

# %% [markdown]
# ###series using read_csv

# %%
#with one coloumn
# note : jab ham date late hai read karte hai toh wo data frame ke form mai hota hai by default uske series mai convert karna padta hai

#squeese isnt supportes in new collab version use .iloc[:,0]

subs=pd.read_csv('/content/subs.csv').iloc[:,0]
print(subs)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-15-2169663636.py in <cell line: 0>()
#       4 #squeese isnt supportes in new collab version use .iloc[:,0]
#       5
# ----> 6 subs=pd.read_csv('/content/subs.csv').iloc[:,0]
#       7 print(subs)
#       8
#
# ...

# %%
#with 2 coloumns
virat=pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').iloc[:,0]
print(virat)

# %%
#indec_col hamko khud se provide karna padt hai laadle
movies=pd.read_csv("/content/bollywood.csv",index_col='movie').iloc[:,0]
print(movies)

# %% [markdown]
# ###series method

# %%
#head and tail

#head is used to give data preview

subs.head()
virat.head(3)

# %%
#tail gives preview of last
virat.tail()
virat.tail(10)

# %%
#sample --> gives select any random value
movies.sample()
movies.sample(5)

# %%
#value_counts-->give frquency of value in decending order

movies.value_counts()

# %%
#sort_values sort values from ascending (default) and decending

# only temporary changes
virat.sort_values(ascending=False).head(1).values  #example of method chaining

# %%
#sort_index --> inplace---> movies
movies.sort_index(ascending=False)

# %%
virat = virat.sort_values()
virat

# %% [markdown]
# ###Mathamatical functions

# %%
#count
#count dosent count missing values where as size does consider them as well

virat.count()

# %%
#sum
subs.sum()
#product
subs.prod()

# %%
#mean/median/mode/std/var
subs.mean()
virat.median()
movies.mode()
subs.std()
virat.var()

# %%
#min/max
subs.max()
subs.min()

# %%
#describe  gives kinda all stst details
virat.describe()

# %% [markdown]
# ###series indexing

# %%
x=pd.Series([12,13,14,35,46,57,58,79,9])
x[0]

# %%
#-ve indexing didnt work here ,, works with +indexing   but -ve index works if index is string

# %%
movies.sort_index(ascending=False)

# %%
movies[0]
movies['1920: London']

# %%
#slicing
virat
virat[5:16:2]

# %%
#fancy indexing

virat[[1,3,4,5]]

# %%
#using lable
movies['1920: London']

# %% [markdown]
# ###editing indexing

# %%
#using indexing
marks_series

# %%
marks_series[1]=100
marks_series

# %%
#what if index dosent exist
#it can add new items in series

marks_series['urdu']=88
marks_series

# %%
runs

# %%
#multi indexing editing
runs[2:4]=[100,100]
runs

# %%
#usinf f slicing
runs[[1,3,4]]=[20,20,20]
runs

# %%
#using lable

movies

# %%
movies['Uri: The Surgical Strike']='ajitesh'
movies

# %% [markdown]
# ###series with python functionalities

# %%
#len/type/dir/sorted/max/min
len(subs)
type(subs)
dir(subs)
sorted(subs)  #prove ans in a list
max(subs)
min(subs)

# %%
#type conversion
marks_series
list(marks_series)
dict(marks_series)

# %%
#member ship operator
movies
'Battalion 609' in movies
'ajitesh' in movies  # it vokes on index not on value
# to ger value use
'ajitesh' in movies.values

# %%
#looping
for i in movies:  # printed the value not index  print value
  print(i)

for i in movies.index:  # now it will print index
  print(i)

# %%
#arthamatic opp (broadcasting)
100-marks_series

# %%
#relational opp
virat

# %%
virat>50

# %%
virat[virat>50]

# %%
virat[virat>100]

# %% [markdown]
# ###plotting graphs on series object  (just use fucking .plot)

# %%
subs.plot()

# %%
movies.value_counts().head(20).plot(kind='bar')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ###some important methods

# %%
import numpy as np
import pandas as pd

# %%
subs=pd.read_csv('/subs.csv').iloc[:,0]
print(type(subs))
movies=pd.read_csv('/bollywood.csv').iloc[:,0]
movies
vk=pd.read_csv('/kohli_ipl.csv').iloc[:,0]
type(vk)

# %%
vk

# %%
import sys
sys.getsizeof(vk)

# %%
#astype which is used to reduce the siz of the data
a=vk.astype('int16')
sys.getsizeof(a)

# %%
#between
vk.between(51,99)
vk[vk.between(51,99)].size

# %%
#clip eg: clip (100,200) toh 100 se kam value 100 anur 200 se zzyada walo values 200 hojaygi beech ki walues same hogi laadle
subs.clip(100,200)

# %%
#drop_duplicates
temp=pd.Series([1,2,2,3,3,4,4])
temp
temp.drop_duplicates()
temp.drop_duplicates(keep='last')

#duplicated to chck if there any duplicate values
temp.duplicated().sum()

# %% [markdown]
# deal with temorory values

# %%
temp=pd.Series([1,2,3,np.nan,5,6,np.nan,np.nan,9,10])

temp.size   #total walues including null
temp.count()  #total values w/o null
#isnull

temp.isnull().sum()

# %%
#dropna
temp.dropna()

# %%
#fillna
temp.fillna(temp.mean())   # will be replaced by zero

# %%
#isin

vk[(vk==49)| (vk==99)]

#or east to avoide conditions

vk[vk.isin([49,99,44])]

# %%
#apply helps to apply custom logic on out table

vk.apply(lambda x:x.split()[0].upper())   #check again

# %%
subs.apply(lambda x: 'good day' if x>subs.mean() else 'bad day')

# %%
#copy copy function crates an new array in which when we name changes dosend make changes in the original data ,where as
#id we use head or tail and make changes the changes also reflect in the original data ,,
print(vk)
new=vk.head()

# %%
new[0]=100
new

# %%
new
vk

# %%
new=vk.head().copy()
new
new[1]=34
new

# %%
vk

# %% [markdown]
# ### Dataframes

# %% [markdown]
# working with 2d tabular data   single columns and rows are known as series and data drame is collection of series , tabular data for us is df for pandas

# %%
import numpy as np
import pandas as pd

# %%
#lists
df=pd.DataFrame([
    [100,80,10],[90,70,9],[120,100,14],[80,50,2]
    ],columns=['ig','marks','package'])

df
# Out:
#     ig  marks  package
# 0  100     80       10
# 1   90     70        9
# 2  120    100       14
# 3   80     50        2

# %%
#dictiornary

df=pd.DataFrame({

                 'iq':[100,90,120,85],
                 'marks':[80,70,100,50],
                 'package':[10,9,14,2]

})
df
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        9
# 2  120    100       14
# 3   85     50        2

# %%
movies=pd.read_csv('/movies.csv')
ipl=pd.read_csv('/ipl-matches.csv')
movies
ipl

# %%
#shape to check rows and coloumns
movies.shape
ipl.shape

# %%
#dtypes  telles ypu data types
movies.dtypes
ipl.dtypes

# %%
#index rage batata hai
movies.index
ipl.index

# %%
#coloumns
movies.columns
ipl.columns

# %%
#values
ipl.values
movies.values

# %%
#head and tail
movies.head()
movies.head(3)
ipl.tail()

# %%
# sample to choose random value
ipl.sample()
ipl.sample()

# %%
#info gives high level information
movies.info()
ipl.info()

# %%
#describe
movies.describe()
ipl.describe()

# %%
#issnull
movies.isnull().sum()
ipl.isnull().sum()

# %%
#duplicated
movies.duplicated()
ipl.duplicated()

# %%
#rename function renames the column name
students.rename(columns={changesg names})   # not not make permanent changes in data
students.rename(columns={changesg names}, inplace=True)  # will make permanet changes in thr data

# %%
import pandas as pd
movies=pd.read_csv('/content/movies.csv')
ipl=pd.read_csv('/content/ipl-matches.csv')

# %% [markdown]
# ###Math method

# %%
#sum --> axia argument

movies.sum()   #here not working
movies.sum(axis=0)  #for row and column wize opperations

# %%
#same as i learn in series but ('axis=0 or 1') because yaha row  wize and column wize opperations lar sakte

# %% [markdown]
# ###Selecting cols and rows from dataframe

# %%
movies
movies['title_x']

# %%
ipl
ipl['Venue']      #a perticulat coloumn is a series

# %% [markdown]
# Multiple cola and rows   #here we use fancy indexing will pass a list

# %%
movies
movies[['title_x','year_of_release','actors']]   #yaha order ham decide kar sakte jiss order mai list pass hogi ussi order mai aayaga op

# %%
ipl
ipl[['WinningTeam','Team1','Team2']]

# %%
#using dictionary

student_dict={
    'name':['aa','bb','cc','dd','ee','ff'],
    'iq':[111,22,120,33,99,88],
    'marks':[33,44,22,55,66,99],
    'package':[10,11,12,14,6,0]
}
students=pd.DataFrame(student_dict)
students
# Out:
#   name   iq  marks  package
# 0   aa  111     33       10
# 1   bb   22     44       11
# 2   cc  120     22       12
# 3   dd   33     55       14
# 4   ee   99     66        6
# 5   ff   88     99        0

# %%
students.set_index('name',inplace=True)
students
# Out:
#        iq  marks  package
# name
# aa    111     33       10
# bb     22     44       11
# cc    120     22       12
# dd     33     55       14
# ee     99     66        6
# ff     88     99        0

# %%
students['iq']
# Out:
# name
# aa    111
# bb     22
# cc    120
# dd     33
# ee     99
# ff     88
# Name: iq, dtype: int64

# %%
## how to fetch rowss from the table
#iloc  search using index position
#loc   search using index lables

# %%
#single row
movies.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
#multiple using iloc
movies.iloc[0:15:3]
# Out:
#                      title_x    imdb_id  \
# 0   Uri: The Surgical Strike  tt8291224
# 3            Why Cheat India  tt8108208
# 6              Fraud Saiyaan  tt5013008
# 9           Thackeray (film)  tt7777196
# 12                 Hum Chaar  tt9319812
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 3   https://upload.wikimedia.org/wikipedia/en/thum...
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 3       https://en.wikipedia.org/wiki/Why_Cheat_India
# 6         https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 9      https://en.wikipedia.org/wiki/Thackeray_(film)
# 12            https://en.wikipedia.org/wiki/Hum_Chaar
#
# ...

# %%
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
#loc
students
# Out:
#        iq  marks  package
# name
# aa    111     33       10
# bb     22     44       11
# cc    120     22       12
# dd     33     55       14
# ee     99     66        6
# ff     88     99        0

# %%
students.loc['aa']
# Out:
# iq         111
# marks       33
# package     10
# Name: aa, dtype: int64

# %%
#mutiple data
students.loc['aa':'ee':2]
students.loc[['aa','bb','dd']]
# Out:
#        iq  marks  package
# name
# aa    111     33       10
# bb     22     44       11
# dd     33     55       14

# %% [markdown]
# ###selecting both rowsa and coloums

# %%
movies.iloc[0:3,0:3]   #behind the scenes
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:3,'title_x':'imdb_id']
# Out:
#                                 title_x    imdb_id
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208

# %% [markdown]
# ###filtering a Data frame

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# find all the winners
winners=ipl[ipl['MatchNumber']=='Final']
winners[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how many super over finishes have occured
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl[ipl['SuperOver']=='Y'].shape[0]
ipl[ipl['SuperOver']=='Y'].count()


      #sum nahi chalege becase integer ahi hai
# Out:
# ID                 14
# City               11
# Date               14
# Season             14
# MatchNumber        14
# Team1              14
# Team2              14
# Venue              14
# TossWinner         14
# TossDecision       14
# SuperOver          14
# WinningTeam        14
# WonBy              14
# Margin              0
# method              0
# Player_of_Match    14
# Team1Players       14
# Team2Players       14
# Umpire1            14
# Umpire2            14
# dtype: int64

# %%
# how many matches csk won in kolkatta
ipl.head()
csk=ipl[ipl['WinningTeam']=='Chennai Super Kings']
csk[csk['City']=='Kolkata'].shape[0]
# Out:
# 5

# %%
#toss winner in match winner percentage    in this we have to compare coloumns
ipl.head()
toss=ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]
total=ipl.shape[0]
(toss/total)*100
# Out:
# 51.473684210526315

# %%
#movies with rating >8 and vottes>1000
movies.head()
movies[(movies['imdb_rating']>8) & (movies['imdb_votes']>10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
#action movies with rating highrt than 7.5
(movies.head())
movies[(movies['genres'].str.split('|').apply(lambda x:'Action' in x)) & (movies['imdb_rating']>7.5)]

movies[(movies['genres'].str.split('|').apply(lambda x:'Action' in x)) & (movies['imdb_rating']>7.5)]
movies[(movies['genres'].str.contains('Action')) & (movies['imdb_rating']>7.5)]  #new way using contains
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
#write a function that can return the trach record of two teams against each other
ipl.head()
w=ipl[(ipl['Team1']=='Royal Challengers Bangalore') & (ipl['Team2']=='Chennai Super Kings') ]
print("total matches",w.shape[0])
print("matches won by rcb",w[w['WinningTeam']=='Royal Challengers Bangalore'].shape[0])
print("matches won by csk",w[w['WinningTeam']=='Chennai Super Kings'].shape[0])
# Out:
# total matches 18
# matches won by rcb 8
# matches won by csk 10

# %% [markdown]
# ###adding new coloums

# %%
#completely new
movies['Country']= 'india'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#using existing coloumns

movies.head()
movies.dropna(inplace=True)

# %%
movies['lead']=movies['actors'].str.split('|').apply(lambda x: x[0])
movies
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ###importand dataframe functions

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
import pandas as pd
ipl=pd.read_csv('/content/ipl-matches.csv')
movies=pd.read_csv('/content/movies.csv')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID']=ipl['ID'].astype('int32')
ipl.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season']=ipl['Season'].astype('category')   #used jisme catagroy sata repeat hota ho waha to reduce size
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#value_count (series and dataframes)

# %%
marks=pd.DataFrame([
    [100,80,10],[90,70,9],[120,100,14],[80,50,2]
    ],columns=['ig','marks','package'])

marks
marks.value_counts()    #frequency of rows  more benficial for series  used in each coloimns wize opperations
# Out:
# ig   marks  package
# 80   50     2          1
# 90   70     9          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
ipl.head(2)
#find player which has won most potm --> finals and qualifiers
ipl[~(ipl['MatchNumber'].str.isdigit())]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#how many matches each team played

(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
#sort_values

movies.head()
#single values
movies['title_x'].sort_values()   #it will ashow only one column only
movies.sort_values('title_x').head(5)  # it will show cpmplete values
# Out:
#                      title_x    imdb_id  \
# 1498      16 December (film)  tt0313844
# 1021             1920 (film)  tt1301698
# 287             1920: London  tt5638500
# 723   1920: The Evil Returns  tt2222550
# 1039        1971 (2007 film)  tt0983990
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link             title_y  \
# 1498   https://en.wikipedia.org/wiki/16_December_(film)              16-Dec
# 1021          https://en.wikipedia.org/wiki/1920_(film)                1920
# 287           https://en.wikipedia.org/wiki/1920_London         1920 London
# ...

# %%
#missing values ko last mai lejata hai
name.sort_values('name',na_position='first',ascending=False)

# %%
#sorting on the basis of multiple coloumns

#pass the list inside sort_values    ascending parameter mai bhi list pass kar sakte hai

movies.sort_values(["year_of_release",'title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#rank(series) only for series

# %%
batsman=pd.read_csv('/content/batsman_runs_ipl.csv')
batsman
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batsman['batting_rank']=batsman['batsman_run'].rank(ascending=False)
batsman.sort_values('batting_rank')
batsman.sort_values("batsman_run",ascending=False)
# Out:
#            batter  batsman_run  batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 63   Abdur Razzak            0         594.0
# 65     Akash Deep            0         594.0
# 562        U Kaul            0         594.0
# 600    Yash Dayal            0         594.0
#
# [605 rows x 3 columns]

# %%
#sort_index
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#ser_index (data frames ) --> inplace (to make permanent change

batsman.set_index('batter',inplace=True)

# %%
batsman
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
#reset_index(series and dataframe)
batsman.reset_index(inplace=True)

# %%
batsman
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
#series ke upar reset   and its also use to convet series to data frame
marks.reset_index()
# Out:
#    index   ig  marks  package
# 0      0  100     80       10
# 1      1   90     70        9
# 2      2  120    100       14
# 3      3   80     50        2

# %%
#rename ( dataframe )

movies.set_index('title_x',inplace=True)

# %%
movies.rename(columns={'imdb_id':'imbd','poster_path':'link'},inplace=True)

# %%
#its also used to rename index values
movies.rename(index={'Uri: The Surgical Strike':'uri'})
# Out:
#                                             imbd  \
# title_x
# uri                                    tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#unique (series)
name.unique #used in series only
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-101-1575222813.py in <cell line: 0>()
#       1 #unique (series)
# ----> 2 name.unique #used in series only
#
# NameError: name 'name' is not defined

# %%
len(ipl['Season'].unique())
# Out:
# 15

# %%
ipl['Season'].nunique()   # it dosent count nana
# Out:
# 15

# %%
#dropna

name.dropna(subset=['column name'])
name.dropna(subset=['col1', 'col2'])   # col1 or col2

#not a permannent change use inplace = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-109-2039735990.py in <cell line: 0>()
#       1 #dropna
#       2
# ----> 3 name.dropna(subset=['column name'])
#
# NameError: name 'name' is not defined

# %%
#find latest match playesd by virat kolhi in delhi
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
name.drop(index=[0:6])  #for series
name.drop(column=['col1','col2'])   #for data frame

# %% [markdown]
# ### Groupby

# %%
movies=pd.read_csv("/content/imdb-top-1000.csv")
movies.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
#groupby hamesha catagorical column pe apply hoga

# %%
genre=movies.groupby('Genre')

# %%
## applying buliitian aggression functions on grouup by objects aggregate functions sum/min/max etc  took the numeric
genre.max()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
#find the top 3 genres by total earning
movies.groupby('Genre').sum()['Gross'].sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
movies.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)  # faster as compared to first
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64
