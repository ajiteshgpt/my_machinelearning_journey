# %%
#netflix case study

# %% [markdown]
# #how to frame a ml problem
#
# 1) business problem to ml problem
#
# 2)types of problems
#
# 3)cureent solution
#
# 4)getting data
#
# 5)mtrices to measure
#
# 6)online vs batch
#
# 7)check assumption

# %% [markdown]
# #data gathering
# 1)csv
#
# 2) json(java scropt on ontation ) data when fetched from api
#
# sql(from data base )
#
# 3)fetching data deom api
#
# 4)web scrapping
#
# other methods are :- big query (google ) , data werehouse , etc

# %% [markdown]
# #Read_csv

# %%
import pandas as pd

# %%
#open drom device
df=pd.read_csv("/content/placement.csv")

# %%
# #open from url

# import requests
# from io import StringIO

# url=""

# headers= {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.8) Gecko/20100101 Firefox/66.0"}

# req =requests.get(url, headers=headers)

# data =StringIO(req.text)

# pd.read_csv(data)

# #just copy the url and it worked

# %%
#sep parameter
#seperated paramteres by default commas uske hisab se colunns banata hai sep=','
# tsv files ho to usme sep='\t'

# %%
#index_col jab col header ban jay
df=pd.read_csv("/content/placement.csv",index_col='cgpa')
df
# Out:
#       Unnamed: 0     iq  placement
# cgpa
# 6.8            0  123.0          1
# 5.9            1  106.0          0
# 5.3            2  121.0          0
# 7.4            3  132.0          1
# 5.8            4  142.0          0
# ...          ...    ...        ...
# 4.3           95  200.0          0
# 4.4           96   42.0          0
# 6.7           97  182.0          1
# 6.3           98  103.0          1
# 6.2           99  113.0          1
#
# [100 rows x 3 columns]

# %%
#headder col ban jay toh
df=pd.read_csv("/content/placement.csv", header =1)

# %%
#use columns , importing specif data from the data

df=pd.read_csv("/content/placement.csv",usecols=['cgpa','placement'])
df
# Out:
#     cgpa  placement
# 0    6.8          1
# 1    5.9          0
# 2    5.3          0
# 3    7.4          1
# 4    5.8          0
# ..   ...        ...
# 95   4.3          0
# 96   4.4          0
# 97   6.7          1
# 98   6.3          1
# 99   6.2          1
#
# [100 rows x 2 columns]

# %%
# df=pd.read_csv("/content/placement.csv",squeeze=True)  #not supported now
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-14-318141197.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("/content/placement.csv",squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
#skip rows/columns

pd.read_csv("/content/placement.csv",skiprows=[0,1])

#we cn import functions an then rows and cols will skip accouring to number
# Out:
#      1  5.9  106.0  0
# 0    2  5.3  121.0  0
# 1    3  7.4  132.0  1
# 2    4  5.8  142.0  0
# 3    5  7.1   48.0  1
# 4    6  5.7  143.0  0
# ..  ..  ...    ... ..
# 93  95  4.3  200.0  0
# 94  96  4.4   42.0  0
# 95  97  6.7  182.0  1
# 96  98  6.3  103.0  1
# 97  99  6.2  113.0  1
#
# [98 rows x 4 columns]

# %%
#n rows will take only n number of rows
pd.read_csv("/content/placement.csv",nrows=20)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# 5            5   7.1   48.0          1
# 6            6   5.7  143.0          0
# 7            7   5.0   63.0          0
# 8            8   6.1  156.0          0
# 9            9   5.1   66.0          0
# 10          10   6.0   45.0          1
# 11          11   6.9  138.0          1
# 12          12   5.4  139.0          0
# 13          13   6.4  116.0          1
# 14          14   6.1  103.0          0
# 15          15   5.1  176.0          0
# 16          16   5.2  224.0          0
# 17          17   3.3  183.0          0
# 18          18   4.0  100.0          0
# 19          19   5.2  132.0          0

# %%
#encoding paramter  encoding in utf 8

#when they are not in utf 8 or code editor mai jake change karo
pd.read_csv("/content/placement.csv",encoding='latin-1')
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
#skip bad lines

#pd.read_csv("/content/placement.csv",error_bad_lines=False)  #old method not supported now
pd.read_csv("/content/placement.csv",on_bad_lines='skip')
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
#dtypes
pd.read_csv("/content/placement.csv",dtype={'iq':int})
# Out:
#     Unnamed: 0  cgpa   iq  placement
# 0            0   6.8  123          1
# 1            1   5.9  106          0
# 2            2   5.3  121          0
# 3            3   7.4  132          1
# 4            4   5.8  142          0
# ..         ...   ...  ...        ...
# 95          95   4.3  200          0
# 96          96   4.4   42          0
# 97          97   6.7  182          1
# 98          98   6.3  103          1
# 99          99   6.2  113          1
#
# [100 rows x 4 columns]

# %%
#handeling dates  usually tratted as string then we cant use date utilities
#pd.read_csv("/content/placement.csv",parse_dates=['date])  it will convert object to date parameters

# %%
#convetors
def rename (name):
  if name==''
    return 'rcb'
  else:
    return name

pd.read_csv("/content/ipl.csv",convertors={'team1':rename})

# %%
#na_values parameters

#will treat a complete column as nan walue
pd.read_csv("/content/placement.csv",na_values=['placement','iq'])
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
#loding a huge dataset in chunks
pd.read_csv("/content/placement.csv",chunksize=100)

# %%
# for chunks in df:
#   print(chunk.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-37-3437725754.py in <cell line: 0>()
#       1 for chunks in df:
# ----> 2   print(chunk.shape)
#
# NameError: name 'chunk' is not defined

# %% [markdown]
# #JSON/SQL

# %%
import pandas as pd

# %%
pd.read_json('/content/train.json')  #converted json file into dataframe and now we can use this data
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# pd.read_json("url") # from url directly
# Out:
# /tmp/ipython-input-40-2048880367.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_json("url") # from url directly
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-40-2048880367.py in <cell line: 0>()
# ----> 1 pd.read_json("url") # from url directly
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# ...

# %% [markdown]
# #SQL

# %%
#need to download software see czmpus x ml day 16 to do this

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 53.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp311-cp311-linux_x86_64.whl size=247951 sha256=1de0642fdbf3ac46c752db625521affc248553c0da54a055048fd1e24c8a9a5b
#   Stored in directory: /root/.cache/pip/wheels/17/cd/ed/2d49e9bac69cf09382e4c7cc20a2511202b48324b87db26019
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
# conn=mysql.connector.connect(host='localhost',user='root',password='',database='world')
# pd.read_sql_query('SELECT *FROM city,conn')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# /tmp/ipython-input-46-4125986875.py in <cell line: 0>()
# ----> 1 mysql.connector.connect(host='localhost',user='root',password='',database='world')
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# ...

# %% [markdown]
# #fetching data from api

# %%
#API:- application programming interface
# helps to communicate bw two softwarea or its a pipeline
#watch campus x video again of needed

# %%
#rapid apis
import pandas as pd
import numpy as np

# %%
import requests

url = "https://imdb236.p.rapidapi.com/api/imdb/tt0816692/tmdb-id"

headers = {
	"x-rapidapi-key": "f7f112ed5cmshcad1216f0b2c385p1c52cajsn591e725b00d3",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'id': 'tt0816692', 'url': 'https://www.imdb.com/title/tt0816692/', 'tmdbId': 'movie/157336'}

# %%
import requests

url = "https://imdb236.p.rapidapi.com/api/imdb/tt0816692/rating"

headers = {
	"x-rapidapi-key": "f7f112ed5cmshcad1216f0b2c385p1c52cajsn591e725b00d3",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-15-3258713701.py in <cell line: 0>()
#      10 response = requests.get(url, headers=headers)
#      11
# ---> 12 df=pd.DataFrame(response.json().set_index('id'))
#
# AttributeError: 'dict' object has no attribute 'set_index'

# %%
import requests

url = "https://covid-193.p.rapidapi.com/countries"

headers = {
	"x-rapidapi-key": "f7f112ed5cmshcad1216f0b2c385p1c52cajsn591e725b00d3",
	"x-rapidapi-host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'countries', 'parameters': [], 'errors': [], 'results': 231, 'response': ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua-and-Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia-and-Herzegovina', 'Botswana', 'Brazil', 'British-Virgin-Islands', 'Brunei', 'Bulgaria', 'Burkina-Faso', 'Burundi', 'Cabo-Verde', 'Cambodia', 'Cameroon', 'Canada', 'CAR', 'Caribbean-Netherlands', 'Cayman-Islands', 'Chad', 'Channel-Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook-Islands', 'Costa-Rica', 'Croatia', 'Cuba', 'Cura&ccedil;ao', 'Cyprus', 'Czechia', 'Denmark', 'Diamond-Princess', 'Djibouti', 'Dominica', 'Dominican-Republic', 'DPRK', 'DRC', 'Ecuador', 'Egypt', 'El-Salvador', 'Equatorial-Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Faeroe-Islands', 'Falkland-Islands', 'Fiji', 'Finl
# ...

# %% [markdown]
# #webscraping

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-27-2671420039.py in <cell line: 0>()
#       1 import pandas as pd
#       2 import requests
# ----> 3 from bs4 import Beaytifulsoup
#
# ImportError: cannot import name 'Beaytifulsoup' from 'bs4' (/usr/local/lib/python3.11/dist-packages/bs4/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install bs4

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers= {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.8) Gecko/20100101 Firefox/66.0"}
requests.get('https://www.ambitionbox.com/list-of-companies?campaign=desktop_nav',headers=headers).text

#we will have to disguise as browser
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#
# ...

# %%
soup=Beautiful
