# %% [markdown]
# #Tasks:
# 1. Load and Inspect the Dataset
# •	Read the dataset into a Pandas DataFrame.
# •	Display the first few rows to understand the structure.
# 2. Identify and Handle Missing Values
# •	Count the number of missing values in each column.
# •	Drop columns that have more than 50% missing values.
# •	Fill missing values:
# o	Numerical columns → Fill with the median.
# o	Categorical columns → Fill with the most frequent value (mode).
# 3. Data Cleaning & Transformation
# •	Convert price to a numeric format (remove "$" symbol and convert to float).
# •	Extract the number of bathrooms from bathrooms_text.
# •	Convert date columns (host_since, first_review, last_review) to datetime.
# •	Convert categorical columns (room_type, property_type, neighbourhood_cleansed) to category.
# 4. Exploratory Data Analysis (EDA) with Visualizations
# •	Distribution of Room Types: Create a bar plot showing the count of each room type.
# •	Price Distribution: Create a histogram to show the distribution of prices.
# •	Geospatial Analysis: Create a scatter plot of listings based on latitude and longitude, colored by price.
# •	Top Hosts: Create a bar chart of the top 10 hosts with the most listings.
# •	Price vs Review Score: Create a scatter plot to analyze the relationship between price and review scores.

# %%
import pandas as pd
import numpy as np

# %%
listing=pd.read_csv('/content/listings.csv')

# %%
listing.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  36121  https://www.airbnb.com/rooms/36121  20250301213336   2025-03-03
# 1  36647  https://www.airbnb.com/rooms/36647  20250301213336   2025-03-03
# 2  38663  https://www.airbnb.com/rooms/38663  20250301213336   2025-03-02
# 3  38833  https://www.airbnb.com/rooms/38833  20250301213336   2025-03-03
# 4  39282  https://www.airbnb.com/rooms/39282  20250301213336   2025-03-02
#
#         source                                               name  \
# 0  city scrape                 Lg Rm in Historic Prospect Heights
# 1  city scrape  1 Bedroom & your own Bathroom, Elevator Apartment
# 2  city scrape                   Luxury Brownstone in Boerum Hill
# 3  city scrape                 Spectacular West Harlem Garden Apt
# 4  city scrape                    “Work-from-home” from OUR home.
#
#                                          description  \
# 0  Cozy space share in the heart of a great neigh...
# 1  Private bedroom with your own bathroom in a 2 ...
# 2  Beautiful, large home in great hipster neighbo...
# 3  This is a very large and unique  space. An inc...
# 4  *Monthly Discount will automatically apply <br...
#
#                                neighborhood_overview  \
# 0  Full of tree-lined streets and beautiful brown...
# 1   Manhattan, SE corner of 2nd Ave/ E. 110th street
# 2  diverse, lively, hip, cool: loaded with restau...
# 3  West Harlem is now packed with great restauran...
# 4  THE NEIGHBORHOOD:<br />Our apartment is locate...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/8776354/35b32...    62165  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...   157798  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...   165789  ...
# 3  https://a0.muscache.com/pictures/7554f9e5-4ab0...   166532  ...
# 4  https://a0.muscache.com/pictures/ef8f43ad-d967...   168525  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   5.00                5.00
# 1                        4.90                   4.38                4.71
# 2                        4.88                   4.86                4.62
# 3                        4.96                   4.79                4.82
# 4                        4.88                   4.85                4.78
#
#               license instant_bookable calculated_host_listings_count  \
# 0                 NaN                f                              1
# 1                 NaN                f                              1
# 2  OSE-STRREG-0001784                f                              1
# 3  OSE-STRREG-0000476                f                              1
# 4  OSE-STRREG-0001150                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.05
# 1                                           0              0.58
# 2                                           0              0.28
# 3                                           0              1.36
# 4                                           0              1.54
#
# [5 rows x 79 columns]

# %%
listing.shape
# Out:
# (37434, 79)

# %%
listing.isnull().sum()
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
#                                                 ...
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                               11787
# Length: 79, dtype: int64

# %%
listing.replace({np.nan:None})
# Out:
#                         id                                       listing_url  \
# 0                    36121                https://www.airbnb.com/rooms/36121
# 1                    36647                https://www.airbnb.com/rooms/36647
# 2                    38663                https://www.airbnb.com/rooms/38663
# 3                    38833                https://www.airbnb.com/rooms/38833
# 4                    39282                https://www.airbnb.com/rooms/39282
# ...                    ...                                               ...
# 37429  1366333532374850165  https://www.airbnb.com/rooms/1366333532374850165
# 37430  1366717321390111215  https://www.airbnb.com/rooms/1366717321390111215
# 37431  1366721904709517353  https://www.airbnb.com/rooms/1366721904709517353
# 37432  1366722692755341871  https://www.airbnb.com/rooms/1366722692755341871
# 37433  1366723228243064949  https://www.airbnb.com/rooms/1366723228243064949
#
#             scrape_id last_scraped       source  \
# 0      20250301213336   2025-03-03  city scrape
# 1      20250301213336   2025-03-03  city scrape
# 2      20250301213336   2025-03-02  city scrape
# 3      20250301213336   2025-03-03  city scrape
# 4      20250301213336   2025-03-02  city scrape
# ...               ...          ...          ...
# 37429  20250301213336   2025-03-02  city scrape
# 37430  20250301213336   2025-03-02  city scrape
# 37431  20250301213336   2025-03-02  city scrape
# 37432  20250301213336   2025-03-02  city scrape
# 37433  20250301213336   2025-03-02  city scrape
#
#                                                     name  \
# 0                     Lg Rm in Historic Prospect Heights
# 1      1 Bedroom & your own Bathroom, Elevator Apartment
# 2                       Luxury Brownstone in Boerum Hill
# 3                     Spectacular West Harlem Garden Apt
# 4                        “Work-from-home” from OUR home.
# ...                                                  ...
# 37429                     Beautiful 1-Bed Apt in Harlem!
# 37430                     Private Room w/ Ensuite Bath H
# 37431                             2 Bedroom on East Side
# 37432                       Stylish 2Bd near Bryant Park
# 37433                       Modern Private Room + Bath H
#
#                                              description  \
# 0      Cozy space share in the heart of a great neigh...
# 1      Private bedroom with your own bathroom in a 2 ...
# 2      Beautiful, large home in great hipster neighbo...
# 3      This is a very large and unique  space. An inc...
# 4      *Monthly Discount will automatically apply <br...
# ...                                                  ...
# 37429  Welcome to your temporary home in the vibrant ...
# 37430  Stylish Private Rooms w/ En-Suite Baths in Bro...
# 37431  Located in the Murray Hill area and occupies a...
# 37432  Enjoy everything the city has to offer while l...
# 37433  Stylish Private Rooms w/ En-Suite Baths in Bro...
#
#                                    neighborhood_overview  \
# 0      Full of tree-lined streets and beautiful brown...
# 1       Manhattan, SE corner of 2nd Ave/ E. 110th street
# 2      diverse, lively, hip, cool: loaded with restau...
# 3      West Harlem is now packed with great restauran...
# 4      THE NEIGHBORHOOD:<br />Our apartment is locate...
# ...                                                  ...
# 37429                                               None
# 37430                                               None
# 37431                                               None
# 37432                                               None
# 37433                                               None
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/8776354/35b32...      62165  ...
# 1      https://a0.muscache.com/pictures/miso/Hosting-...     157798  ...
# 2      https://a0.muscache.com/pictures/miso/Hosting-...     165789  ...
# 3      https://a0.muscache.com/pictures/7554f9e5-4ab0...     166532  ...
# 4      https://a0.muscache.com/pictures/ef8f43ad-d967...     168525  ...
# ...                                                  ...        ...  ...
# 37429  https://a0.muscache.com/pictures/miso/Hosting-...   40019013  ...
# 37430  https://a0.muscache.com/pictures/miso/Hosting-...  483056418  ...
# 37431  https://a0.muscache.com/pictures/miso/Hosting-...   30283594  ...
# 37432  https://a0.muscache.com/pictures/miso/Hosting-...  407304997  ...
# 37433  https://a0.muscache.com/pictures/miso/Hosting-...  483056418  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                             5.0                    5.0                 5.0
# 1                             4.9                   4.38                4.71
# 2                            4.88                   4.86                4.62
# 3                            4.96                   4.79                4.82
# 4                            4.88                   4.85                4.78
# ...                           ...                    ...                 ...
# 37429                        None                   None                None
# 37430                        None                   None                None
# 37431                        None                   None                None
# 37432                        None                   None                None
# 37433                        None                   None                None
#
#                   license instant_bookable calculated_host_listings_count  \
# 0                    None                f                              1
# 1                    None                f                              1
# 2      OSE-STRREG-0001784                f                              1
# 3      OSE-STRREG-0000476                f                              1
# 4      OSE-STRREG-0001150                f                              2
# ...                   ...              ...                            ...
# 37429                None                f                              1
# 37430                None                f                             24
# 37431                None                f                             48
# 37432                None                t                             25
# 37433                None                f                             24
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               1
# 4                                               0
# ...                                           ...
# 37429                                           0
# 37430                                           0
# 37431                                          48
# 37432                                          25
# 37433                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                1
# 2                                                1
# 3                                                0
# 4                                                2
# ...                                            ...
# 37429                                            1
# 37430                                           24
# 37431                                            0
# 37432                                            0
# 37433                                           24
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.05
# 1                                               0              0.58
# 2                                               0              0.28
# 3                                               0              1.36
# 4                                               0              1.54
# ...                                           ...               ...
# 37429                                           0              None
# 37430                                           0              None
# 37431                                           0              None
# 37432                                           0              None
# 37433                                           0              None
#
# [37434 rows x 79 columns]

# %%
drop_columns = ['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'picture_url',
                'host_id', 'host_url', 'host_thumbnail_url', 'host_picture_url', 'calendar_updated', 'license',
                'description', 'neighborhood_overview', 'host_about', 'host_response_time', 'host_response_rate',
                'host_acceptance_rate', 'host_is_superhost', 'host_location', 'host_listings_count',
                'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
                'neighbourhood_cleansed', 'minimum_minimum_nights', 'maximum_minimum_nights',
                'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm',
                'maximum_nights_avg_ntm', 'calendar_last_scraped', 'has_availability', 'availability_eoy',
                'number_of_reviews_ltm', 'number_of_reviews_l30d', 'number_of_reviews_ly', 'estimated_occupancy_l365d',
                'estimated_revenue_l365d', 'instant_bookable', 'calculated_host_listings_count',
                'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms',
                'calculated_host_listings_count_shared_rooms']

listing.drop(columns=drop_columns,inplace=True)

# %%
listing.isnull().sum()
listing.shape
# Out:
# (37434, 34)

# %%
listing
# Out:
#                                                     name  \
# 0                     Lg Rm in Historic Prospect Heights
# 1      1 Bedroom & your own Bathroom, Elevator Apartment
# 2                       Luxury Brownstone in Boerum Hill
# 3                     Spectacular West Harlem Garden Apt
# 4                        “Work-from-home” from OUR home.
# ...                                                  ...
# 37429                     Beautiful 1-Bed Apt in Harlem!
# 37430                     Private Room w/ Ensuite Bath H
# 37431                             2 Bedroom on East Side
# 37432                       Stylish 2Bd near Bryant Park
# 37433                       Modern Private Room + Bath H
#
#                   host_name  host_since  host_neighbourhood  \
# 0                   Michael  2009-12-11    Prospect Heights
# 1                     Irene  2010-07-04         East Harlem
# 2                     Sarah  2010-07-13         Boerum Hill
# 3                   Matthew  2010-07-14              Harlem
# 4                   Gustavo  2010-07-16        Williamsburg
# ...                     ...         ...                 ...
# 37429               Cecilia  2015-07-30                 NaN
# 37430              Kristina  2022-10-10  Bedford-Stuyvesant
# 37431  Global Luxury Suites  2015-03-30         Miami Beach
# 37432             Boomerang  2021-06-15          Park Slope
# 37433              Kristina  2022-10-10  Bedford-Stuyvesant
#
#                  neighbourhood neighbourhood_group_cleansed   latitude  \
# 0      Neighborhood highlights                     Brooklyn  40.673760
# 1      Neighborhood highlights                    Manhattan  40.792454
# 2      Neighborhood highlights                     Brooklyn  40.684420
# 3      Neighborhood highlights                    Manhattan  40.818058
# 4      Neighborhood highlights                     Brooklyn  40.710651
# ...                        ...                          ...        ...
# 37429                      NaN                    Manhattan  40.813794
# 37430                      NaN                     Brooklyn  40.685500
# 37431                      NaN                    Manhattan  40.745290
# 37432                      NaN                    Manhattan  40.757133
# 37433                      NaN                     Brooklyn  40.685500
#
#        longitude                property_type        room_type  ...  \
# 0     -73.966110  Private room in rental unit     Private room  ...
# 1     -73.940742        Private room in condo     Private room  ...
# 2     -73.980680         Private room in home     Private room  ...
# 3     -73.946671                  Entire home  Entire home/apt  ...
# 4     -73.950874  Private room in rental unit     Private room  ...
# ...          ...                          ...              ...  ...
# 37429 -73.952399  Private room in rental unit     Private room  ...
# 37430 -73.919510  Private room in rental unit     Private room  ...
# 37431 -73.979380           Entire rental unit  Entire home/apt  ...
# 37432 -73.983124           Entire rental unit  Entire home/apt  ...
# 37433 -73.919510  Private room in rental unit     Private room  ...
#
#        first_review  last_review review_scores_rating  review_scores_accuracy  \
# 0        2010-12-11   2013-05-10                 4.88                    5.00
# 1        2010-10-04   2023-12-09                 4.77                    4.82
# 2        2012-07-09   2023-08-30                 4.70                    4.83
# 3        2010-08-28   2025-02-21                 4.85                    4.87
# 4        2010-08-02   2025-01-03                 4.82                    4.83
# ...             ...          ...                  ...                     ...
# 37429           NaN          NaN                  NaN                     NaN
# 37430           NaN          NaN                  NaN                     NaN
# 37431           NaN          NaN                  NaN                     NaN
# 37432           NaN          NaN                  NaN                     NaN
# 37433           NaN          NaN                  NaN                     NaN
#
#        review_scores_cleanliness review_scores_checkin  \
# 0                           4.80                  5.00
# 1                           4.76                  4.88
# 2                           4.52                  4.88
# 3                           4.50                  4.96
# 4                           4.61                  4.94
# ...                          ...                   ...
# 37429                        NaN                   NaN
# 37430                        NaN                   NaN
# 37431                        NaN                   NaN
# 37432                        NaN                   NaN
# 37433                        NaN                   NaN
#
#       review_scores_communication  review_scores_location  \
# 0                            5.00                    5.00
# 1                            4.90                    4.38
# 2                            4.88                    4.86
# 3                            4.96                    4.79
# 4                            4.88                    4.85
# ...                           ...                     ...
# 37429                         NaN                     NaN
# 37430                         NaN                     NaN
# 37431                         NaN                     NaN
# 37432                         NaN                     NaN
# 37433                         NaN                     NaN
#
#        review_scores_value  reviews_per_month
# 0                     5.00               0.05
# 1                     4.71               0.58
# 2                     4.62               0.28
# 3                     4.82               1.36
# 4                     4.78               1.54
# ...                    ...                ...
# 37429                  NaN                NaN
# 37430                  NaN                NaN
# 37431                  NaN                NaN
# 37432                  NaN                NaN
# 37433                  NaN                NaN
#
# [37434 rows x 34 columns]

# %%
listing=listing.dropna(axis=1,thresh=listing.count()/2)

# %%
listing
# Out:
#                                                     name  \
# 0                     Lg Rm in Historic Prospect Heights
# 1      1 Bedroom & your own Bathroom, Elevator Apartment
# 2                       Luxury Brownstone in Boerum Hill
# 3                     Spectacular West Harlem Garden Apt
# 4                        “Work-from-home” from OUR home.
# ...                                                  ...
# 37429                     Beautiful 1-Bed Apt in Harlem!
# 37430                     Private Room w/ Ensuite Bath H
# 37431                             2 Bedroom on East Side
# 37432                       Stylish 2Bd near Bryant Park
# 37433                       Modern Private Room + Bath H
#
#                   host_name  host_since  host_neighbourhood  \
# 0                   Michael  2009-12-11    Prospect Heights
# 1                     Irene  2010-07-04         East Harlem
# 2                     Sarah  2010-07-13         Boerum Hill
# 3                   Matthew  2010-07-14              Harlem
# 4                   Gustavo  2010-07-16        Williamsburg
# ...                     ...         ...                 ...
# 37429               Cecilia  2015-07-30                 NaN
# 37430              Kristina  2022-10-10  Bedford-Stuyvesant
# 37431  Global Luxury Suites  2015-03-30         Miami Beach
# 37432             Boomerang  2021-06-15          Park Slope
# 37433              Kristina  2022-10-10  Bedford-Stuyvesant
#
#                  neighbourhood neighbourhood_group_cleansed   latitude  \
# 0      Neighborhood highlights                     Brooklyn  40.673760
# 1      Neighborhood highlights                    Manhattan  40.792454
# 2      Neighborhood highlights                     Brooklyn  40.684420
# 3      Neighborhood highlights                    Manhattan  40.818058
# 4      Neighborhood highlights                     Brooklyn  40.710651
# ...                        ...                          ...        ...
# 37429                      NaN                    Manhattan  40.813794
# 37430                      NaN                     Brooklyn  40.685500
# 37431                      NaN                    Manhattan  40.745290
# 37432                      NaN                    Manhattan  40.757133
# 37433                      NaN                     Brooklyn  40.685500
#
#        longitude                property_type        room_type  ...  \
# 0     -73.966110  Private room in rental unit     Private room  ...
# 1     -73.940742        Private room in condo     Private room  ...
# 2     -73.980680         Private room in home     Private room  ...
# 3     -73.946671                  Entire home  Entire home/apt  ...
# 4     -73.950874  Private room in rental unit     Private room  ...
# ...          ...                          ...              ...  ...
# 37429 -73.952399  Private room in rental unit     Private room  ...
# 37430 -73.919510  Private room in rental unit     Private room  ...
# 37431 -73.979380           Entire rental unit  Entire home/apt  ...
# 37432 -73.983124           Entire rental unit  Entire home/apt  ...
# 37433 -73.919510  Private room in rental unit     Private room  ...
#
#        first_review  last_review review_scores_rating  review_scores_accuracy  \
# 0        2010-12-11   2013-05-10                 4.88                    5.00
# 1        2010-10-04   2023-12-09                 4.77                    4.82
# 2        2012-07-09   2023-08-30                 4.70                    4.83
# 3        2010-08-28   2025-02-21                 4.85                    4.87
# 4        2010-08-02   2025-01-03                 4.82                    4.83
# ...             ...          ...                  ...                     ...
# 37429           NaN          NaN                  NaN                     NaN
# 37430           NaN          NaN                  NaN                     NaN
# 37431           NaN          NaN                  NaN                     NaN
# 37432           NaN          NaN                  NaN                     NaN
# 37433           NaN          NaN                  NaN                     NaN
#
#        review_scores_cleanliness review_scores_checkin  \
# 0                           4.80                  5.00
# 1                           4.76                  4.88
# 2                           4.52                  4.88
# 3                           4.50                  4.96
# 4                           4.61                  4.94
# ...                          ...                   ...
# 37429                        NaN                   NaN
# 37430                        NaN                   NaN
# 37431                        NaN                   NaN
# 37432                        NaN                   NaN
# 37433                        NaN                   NaN
#
#       review_scores_communication  review_scores_location  \
# 0                            5.00                    5.00
# 1                            4.90                    4.38
# 2                            4.88                    4.86
# 3                            4.96                    4.79
# 4                            4.88                    4.85
# ...                           ...                     ...
# 37429                         NaN                     NaN
# 37430                         NaN                     NaN
# 37431                         NaN                     NaN
# 37432                         NaN                     NaN
# 37433                         NaN                     NaN
#
#        review_scores_value  reviews_per_month
# 0                     5.00               0.05
# 1                     4.71               0.58
# 2                     4.62               0.28
# 3                     4.82               1.36
# 4                     4.78               1.54
# ...                    ...                ...
# 37429                  NaN                NaN
# 37430                  NaN                NaN
# 37431                  NaN                NaN
# 37432                  NaN                NaN
# 37433                  NaN                NaN
#
# [37434 rows x 34 columns]

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37434 entries, 0 to 37433
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          37432 non-null  object
#  1   host_name                     37396 non-null  object
#  2   host_since                    37396 non-null  object
#  3   host_neighbourhood            29718 non-null  object
#  4   neighbourhood                 20225 non-null  object
#  5   neighbourhood_group_cleansed  37434 non-null  object
#  6   latitude                      37434 non-null  float64
#  7   longitude                     37434 non-null  float64
#  8   property_type                 37434 non-null  object
#  9   room_type                     37434 non-null  object
#  10  accommodates                  37434 non-null  int64
#  11  bathrooms                     22503 non-null  float64
#  12  bathrooms_text                37404 non-null  object
#  13  bedrooms                      31523 non-null  float64
#  14  beds                          22352 non-null  float64
#  15  amenities                     37434 non-null  object
#  16  price                         22308 non-null  object
#  17  minimum_nights                37434 non-null  int64
#  18  maximum_nights                37434 non-null  int64
#  19  availability_30               37434 non-null  int64
#  20  availability_60               37434 non-null  int64
#  21  availability_90               37434 non-null  int64
#  22  availability_365              37434 non-null  int64
#  23  number_of_reviews             37434 non-null  int64
#  24  first_review                  25647 non-null  object
#  25  last_review                   25647 non-null  object
#  26  review_scores_rating          25647 non-null  float64
#  27  review_scores_accuracy        25636 non-null  float64
#  28  review_scores_cleanliness     25646 non-null  float64
#  29  review_scores_checkin         25632 non-null  float64
#  30  review_scores_communication   25641 non-null  float64
#  31  review_scores_location        25629 non-null  float64
#  32  review_scores_value           25630 non-null  float64
#  33  reviews_per_month             25647 non-null  float64
# dtypes: float64(13), int64(8), object(13)
# memory usage: 9.7+ MB

# %%
avg=listing.select_dtypes(include='number').columns
listing[avg]=listing[avg].apply(lambda x: x.fillna(x.median()))

# %%
num_cols=listing.select_dtypes(include='number').columns

# %%
listing
# Out:
#                                                     name  \
# 0                     Lg Rm in Historic Prospect Heights
# 1      1 Bedroom & your own Bathroom, Elevator Apartment
# 2                       Luxury Brownstone in Boerum Hill
# 3                     Spectacular West Harlem Garden Apt
# 4                        “Work-from-home” from OUR home.
# ...                                                  ...
# 37429                     Beautiful 1-Bed Apt in Harlem!
# 37430                     Private Room w/ Ensuite Bath H
# 37431                             2 Bedroom on East Side
# 37432                       Stylish 2Bd near Bryant Park
# 37433                       Modern Private Room + Bath H
#
#                   host_name  host_since  host_neighbourhood  \
# 0                   Michael  2009-12-11    Prospect Heights
# 1                     Irene  2010-07-04         East Harlem
# 2                     Sarah  2010-07-13         Boerum Hill
# 3                   Matthew  2010-07-14              Harlem
# 4                   Gustavo  2010-07-16        Williamsburg
# ...                     ...         ...                 ...
# 37429               Cecilia  2015-07-30                 NaN
# 37430              Kristina  2022-10-10  Bedford-Stuyvesant
# 37431  Global Luxury Suites  2015-03-30         Miami Beach
# 37432             Boomerang  2021-06-15          Park Slope
# 37433              Kristina  2022-10-10  Bedford-Stuyvesant
#
#                  neighbourhood neighbourhood_group_cleansed   latitude  \
# 0      Neighborhood highlights                     Brooklyn  40.673760
# 1      Neighborhood highlights                    Manhattan  40.792454
# 2      Neighborhood highlights                     Brooklyn  40.684420
# 3      Neighborhood highlights                    Manhattan  40.818058
# 4      Neighborhood highlights                     Brooklyn  40.710651
# ...                        ...                          ...        ...
# 37429                      NaN                    Manhattan  40.813794
# 37430                      NaN                     Brooklyn  40.685500
# 37431                      NaN                    Manhattan  40.745290
# 37432                      NaN                    Manhattan  40.757133
# 37433                      NaN                     Brooklyn  40.685500
#
#        longitude                property_type        room_type  ...  \
# 0     -73.966110  Private room in rental unit     Private room  ...
# 1     -73.940742        Private room in condo     Private room  ...
# 2     -73.980680         Private room in home     Private room  ...
# 3     -73.946671                  Entire home  Entire home/apt  ...
# 4     -73.950874  Private room in rental unit     Private room  ...
# ...          ...                          ...              ...  ...
# 37429 -73.952399  Private room in rental unit     Private room  ...
# 37430 -73.919510  Private room in rental unit     Private room  ...
# 37431 -73.979380           Entire rental unit  Entire home/apt  ...
# 37432 -73.983124           Entire rental unit  Entire home/apt  ...
# 37433 -73.919510  Private room in rental unit     Private room  ...
#
#        first_review  last_review review_scores_rating  review_scores_accuracy  \
# 0        2010-12-11   2013-05-10                 4.88                    5.00
# 1        2010-10-04   2023-12-09                 4.77                    4.82
# 2        2012-07-09   2023-08-30                 4.70                    4.83
# 3        2010-08-28   2025-02-21                 4.85                    4.87
# 4        2010-08-02   2025-01-03                 4.82                    4.83
# ...             ...          ...                  ...                     ...
# 37429           NaN          NaN                 4.86                    4.90
# 37430           NaN          NaN                 4.86                    4.90
# 37431           NaN          NaN                 4.86                    4.90
# 37432           NaN          NaN                 4.86                    4.90
# 37433           NaN          NaN                 4.86                    4.90
#
#        review_scores_cleanliness review_scores_checkin  \
# 0                           4.80                  5.00
# 1                           4.76                  4.88
# 2                           4.52                  4.88
# 3                           4.50                  4.96
# 4                           4.61                  4.94
# ...                          ...                   ...
# 37429                       4.81                  4.95
# 37430                       4.81                  4.95
# 37431                       4.81                  4.95
# 37432                       4.81                  4.95
# 37433                       4.81                  4.95
#
#       review_scores_communication  review_scores_location  \
# 0                            5.00                    5.00
# 1                            4.90                    4.38
# 2                            4.88                    4.86
# 3                            4.96                    4.79
# 4                            4.88                    4.85
# ...                           ...                     ...
# 37429                        4.96                    4.85
# 37430                        4.96                    4.85
# 37431                        4.96                    4.85
# 37432                        4.96                    4.85
# 37433                        4.96                    4.85
#
#        review_scores_value  reviews_per_month
# 0                     5.00               0.05
# 1                     4.71               0.58
# 2                     4.62               0.28
# 3                     4.82               1.36
# 4                     4.78               1.54
# ...                    ...                ...
# 37429                 4.76               0.27
# 37430                 4.76               0.27
# 37431                 4.76               0.27
# 37432                 4.76               0.27
# 37433                 4.76               0.27
#
# [37434 rows x 34 columns]

# %%
cat_col=listing.select_dtypes(include='object').columns

listing[cat_col]=listing[cat_col].fillna(listing[cat_col].mode().iloc[0])

# %%
listing.head(2)
# Out:
#                                                 name host_name  host_since  \
# 0                 Lg Rm in Historic Prospect Heights   Michael  2009-12-11
# 1  1 Bedroom & your own Bathroom, Elevator Apartment     Irene  2010-07-04
#
#   host_neighbourhood            neighbourhood neighbourhood_group_cleansed  \
# 0   Prospect Heights  Neighborhood highlights                     Brooklyn
# 1        East Harlem  Neighborhood highlights                    Manhattan
#
#     latitude  longitude                property_type     room_type  ...  \
# 0  40.673760 -73.966110  Private room in rental unit  Private room  ...
# 1  40.792454 -73.940742        Private room in condo  Private room  ...
#
#    first_review  last_review review_scores_rating  review_scores_accuracy  \
# 0    2010-12-11   2013-05-10                 4.88                    5.00
# 1    2010-10-04   2023-12-09                 4.77                    4.82
#
#    review_scores_cleanliness review_scores_checkin  \
# 0                       4.80                  5.00
# 1                       4.76                  4.88
#
#   review_scores_communication  review_scores_location  review_scores_value  \
# 0                         5.0                    5.00                 5.00
# 1                         4.9                    4.38                 4.71
#
#    reviews_per_month
# 0               0.05
# 1               0.58
#
# [2 rows x 34 columns]

# %%
listing['price'] = listing['price'].astype(str).str.replace('$', '',regex=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-119-1749953736.py in <cell line: 0>()
# ----> 1 listing['price'] = listing['price'].astype(str).str.replace('$', '',regex=True).astype(float)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     131     if copy or arr.dtype == object or dtype == object:
#     132         # Explicit copy, or required since NumPy can't view from / to object.
# --> 133         return arr.astype(dtype, copy=True)
#     134
#     135     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '2,500.00'

# %%
listing['price'].dropna()
# Out:
# 0        200.00
# 1         82.00
# 2        765.00
# 3        139.00
# 4        130.00
#           ...
# 37429     72.00
# 37430     58.00
# 37431    299.00
# 37432    200.00
# 37433     58.00
# Name: price, Length: 37434, dtype: object

# %%
listing['bathrooms_text'].dropna()
listing['bathrooms_text'].str.split().apply(lambda x: x[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-128-3626397812.py in <cell line: 0>()
#       1 listing['bathrooms_text'].dropna()
# ----> 2 listing['bathrooms_text'].str.split().apply(lambda x: x[0])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipython-input-128-3626397812.py in <lambda>(x)
#       1 listing['bathrooms_text'].dropna()
# ----> 2 listing['bathrooms_text'].str.split().apply(lambda x: x[0])
#
# TypeError: 'float' object is not subscriptable

# %%
categorical_columns = ['room_type', 'property_type', 'neighbourhood_group_cleansed']
for col in categorical_columns:
    listing[col] = listing[col].astype('category')

display(listing[categorical_columns].head())
display(listing[categorical_columns].info())
