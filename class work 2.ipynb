# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Placement_Data.csv")

# %%
df.head(20)
df.tail(5)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 210    211      M   80.6   Others   82.0  Others  Commerce      77.6
# 211    212      M   58.0   Others   60.0  Others   Science      72.0
# 212    213      M   67.0   Others   67.0  Others  Commerce      73.0
# 213    214      F   74.0   Others   66.0  Others  Commerce      58.0
# 214    215      M   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %%
df.columns
df.shape
# Out:
# (215, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
#how many toppers in class
df[df['ssc_p']==df['ssc_p'].max()].shape[0]
# Out:
# 1

# %%
#is topper placed
df[df['ssc_p']==df['ssc_p'].max()]["status"]
# Out:
# 145    Placed
# Name: status, dtype: object

# %%
#how many are placed or not
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df['status'].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %%
148/215
# Out:
# 0.6883720930232559

# %%
#most common degree
df[df['status']=='Placed']['degree_t'].value_counts().head(1)
# Out:
# degree_t
# Comm&Mgmt    102
# Name: count, dtype: int64

# %%
#how many unique degrees
df['degree_t'].nunique()
# Out:
# 3

# %%
#corrrlation bw 10th and 12th
df[['ssc_p','hsc_p']].corr()
# Out:
#           ssc_p     hsc_p
# ssc_p  1.000000  0.511472
# hsc_p  0.511472  1.000000

# %%
df.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
#to make corellation matrix of numeric values then because aaise nhi hota hai aur bhi values hoti haito hame pehle numercical values lenei padegi
numeric_df=df.select_dtypes(include='number')

# %%
numeric_df.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# #data preprocessing

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.sample(5)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 140    141      M   65.0  Central   64.8   Others  Commerce     69.50
# 115    116      F   73.0   Others   63.0   Others   Science     66.00
# 114    115      M   65.0  Central   68.0   Others   Science     69.00
# 126    127      F   79.0   Others   61.0   Others   Science     75.50
# 124    125      M   67.0  Central   71.0  Central   Science     64.33
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 140  Comm&Mgmt    Yes     56.0        Mkt&Fin  56.94  Placed  265000.0
# 115  Comm&Mgmt     No     89.0        Mkt&Fin  60.50  Placed  216000.0
# 114  Comm&Mgmt     No     53.7         Mkt&HR  55.01  Placed  250000.0
# 126   Sci&Tech    Yes     70.0        Mkt&Fin  68.20  Placed  210000.0
# 124     Others    Yes     64.0         Mkt&HR  61.26  Placed  250000.0

# %%
df.drop(columns=['sl_no'],inplace=True)

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status    salary
# 0     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status    salary
# 0     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#scatter plot bw 10th and 12th percentage
sns.scatterplot(x='ssc_p',y='hsc_p',data=df)
plt.title("scatter plot bw 10th and 12th")
# Out:
# Text(0.5, 1.0, 'scatter plot bw 10th and 12th')

# %%
sns.scatterplot(x='ssc_p',y='hsc_p',data=df,hue='status')
plt.title("scatter plot bw 10th and 12th")
# Out:
# Text(0.5, 1.0, 'scatter plot bw 10th and 12th')

# %%
sns.pairplot(df,hue='status',diag_kind='hist')

# %%
#draw boxplot for 10th percentage
sns.boxplot(df['ssc_p'])
# Out:
# <Axes: ylabel='ssc_p'>

# %%
#boxplot of 12th
sns.boxplot(df['ssc_p'])
# Out:
# <Axes: ylabel='ssc_p'>

# %%
sns.boxplot(x='status',y='ssc_p',data=df)
# Out:
# <Axes: xlabel='status', ylabel='ssc_p'>

# %%
#to be continue

# %% [markdown]
# #lable encoding

# %%
df
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['ssc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
df['ssc_b']=le.fit_transform(df['ssc_b'])

# %%
df['ssc_b'].unique()
# Out:
# array([1, 0])

# %%
df
# Out:
#     gender  ssc_p  ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00      1  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33      0  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00      0  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00      0  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80      0  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...    ...    ...      ...       ...       ...        ...
# 210      M  80.60      1  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00      1  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00      1  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00      1  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00      0  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='object')

# %%
col=['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
       'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
       'salary']

# %%
for i in col:
  df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#      gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0         1     46      1     93      1      1        14         2       0
# 1         1     82      0     79      1      2        74         2       1
# 2         1     42      0     51      0      0        27         0       0
# 3         1     22      0     14      0      2         3         2       0
# 4         1     98      0     70      0      1        65         0       0
# ..      ...    ...    ...    ...    ...    ...       ...       ...     ...
# 210       1     85      1     84      1      1        76         0       0
# 211       1     25      1     24      1      2        60         2       0
# 212       1     46      1     49      1      1        64         0       1
# 213       0     64      1     45      1      1        14         0       0
# 214       1     36      0     21      1      2         4         0       0
#
#      etest_p  specialisation  mba_p  status  salary
# ...

# %%
X=df.iloc[:,0:-1]

# %%
Y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.70710678, -0.56170443,  1.        , ...,  1.15920231,
#          0.26828733, -1.45773797],
#        [ 0.70710678,  1.58540828,  1.        , ..., -0.86266219,
#         -0.52655277,  0.68599434],
#        [ 0.70710678, -1.45016486,  1.        , ..., -0.86266219,
#         -0.42287798, -1.45773797],
#        ...,
#        [-1.41421356,  1.03012051, -1.        , ..., -0.86266219,
#          0.95945264,  0.68599434],
#        [-1.41421356,  1.10415888,  1.        , ..., -0.86266219,
#          1.27047703,  0.68599434],
#        [ 0.70710678, -0.96891546, -1.        , ..., -0.86266219,
#         -1.68425466, -1.45773797]])

# %%
X_tesr=sc.fit_transform(X_test)

# %% [markdown]
# #linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# np.float64(13.093333333333334)

# %%
lr.coef_
# Out:
# array([ 2.05720066,  0.58405107,  1.12551376, -0.19997372, -1.13580721,
#        -0.28998342, -1.68468593,  1.35900695, -0.64568473,  1.08880531,
#        -1.04806254,  2.2881629 ,  8.86947003])

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([267.58078332, 125.04816513, 152.94294081, 348.47999564,
#        250.91322919, 411.27477561, 325.20567435, 123.72642703,
#        473.4022049 , 200.03258672, 488.97612978,  56.25611861,
#        361.7092091 , 285.82463257, 319.46802937, 256.08000623,
#        163.86619806, 544.28391339,  88.39279815, 166.76941209,
#         52.61089675, 117.30242013, 458.25202102, 203.98784719,
#        176.90281265, 213.64535273, 409.08847573, 142.89297655,
#        290.12721704, 436.42670321, 446.76005671, 308.97075623,
#        249.24419547, 412.95787314, 400.2612472 , 333.22628915,
#         41.02987058, 199.13992523, 447.81257916, 126.05814977,
#        129.55682924, 431.4169151 ,  64.97375204, 265.38617435,
#        142.35247633, 405.89961336, 324.83007792, 184.10569918,
#        248.69933126, 353.14452397, 314.22809677, 167.15740557,
#        315.77814309, 113.82119443, 500.68210719, 160.28978911,
#        191.95025931, 249.87306906, 357.55617223, 150.56011147,
# ...

# %%
Y_test
# Out:
# 115     4
# 27     18
# 144     0
# 119    45
# 8       9
#        ..
# 198     0
# 59     18
# 114    13
# 57     34
# 20     18
# Name: salary, Length: 65, dtype: int64
