# %% [markdown]
# #encoding of numerical data

# %% [markdown]
# #discretization(binning)

# %% [markdown]
# Discretization is a process of transforming continues variable into discrete variables by creating a set of Cottages intervals that span the range of variables value discretization is also called binning where bin is an alternative name for interval
#
# Why we use discretization:
#
# to handle outliners
#
# to improve the value spread
#
#
# types:
#
# 1)unsuperwized(equal width binning (unifirm binning ), equal frequency (quantile) , kmeans binning )
#
# 2) superwised ( decision treee binning)
#
# 3)custom binning

# %% [markdown]
# #equal width/uniform binning
#  (max-min)/no of bins
#
#  outliners ko deal karte hai and there is no change of graph spread

# %% [markdown]
# #equal frequency and quantile binning
#
# intervals =10
#
# that means each interval contains 10% of total observations
#
#
# log same rehte hsi lekin width alag rehti hai /interval

# %% [markdown]
# #k means binning
#
# in this we use a clustering algoriths , it can make cluster in ant dimentions , yaha pr interval ko centroid bolte hai

# %% [markdown]
# #encoding the desceetized variable
#
#
# sklearn --> kBinsDiscretizer ( bins , catagory ( uniform , quantile , kmeans ), encoding (ordinal , one hot encoding ))

# %%
import pandas as pd
import numpy as np

import matplotlib as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier


from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
df =pd.read_csv("/content/train.csv",usecols=['Age',"Fare",'Survived'])

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (714, 3)

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(['Survived'],axis=1),df['Survived'],test_size=0.2,random_state=42)

# %%
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.6223776223776224

# %%
np.mean(cross_val_score(clf,,,cv=10,scoring='accuracy'))
# Out:
# np.float64(0.6200241984271022)

# %% [markdown]
# #apllying descritizer

# %%
kbin_age=KBinsDiscretizer(n_bins=10,encode='ordinal',strategy='quantile')
kbin_fare=KBinsDiscretizer(n_bins=10,encode='ordinal',strategy='quantile')

# %%
trf=ColumnTransformer((
    ('first',kbin_age,[0]),
    ('second',kbin_fare,[1])
))

# %%
x_train_trf=trf.fit_transform(x_train)
x_test_trf=trf.fit_transform(x_test)

# %%
output = pd.DataFrame({
    'age':x_train['Age'],
    'age_trf':x_train_trf[:,0],
    'fare':x_train['Fare'],
    'fare_trf':x_train_trf[:,1]
})
output['age_labels'] = pd.cut(x=x_train['Age'],
                                    bins=trf.named_transformers_['first'].bin_edges_[0].tolist())
output['fare_labels'] = pd.cut(x=x_train['Fare'],
                                    bins=trf.named_transformers_['second'].bin_edges_[0].tolist())
output.sample(5)
# Out:
#       age  age_trf   fare  fare_trf    age_labels        fare_labels
# 717  27.0      4.0  10.50       3.0  (24.0, 28.0]      (8.662, 10.5]
# 412  33.0      6.0  90.00       9.0  (30.1, 34.4]  (57.783, 512.329]
# 191  19.0      2.0  13.00       4.0  (17.0, 20.6]     (10.5, 14.454]
# 699  42.0      8.0   7.65       0.0  (38.6, 47.8]       (0.0, 7.743]
# 160  44.0      8.0  16.10       5.0  (38.6, 47.8]    (14.454, 22.62]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-39-3104435723.py in <cell line: 0>()
#      33     plt.show()
#      34
# ---> 35 discretize(5,'kmeans')
#
# /tmp/ipython-input-39-3104435723.py in discretize(bins, strategy)
#       8     ])
#       9
# ---> 10     x_trf = trf.fit_transform(X)
#      11     print(np.mean(cross_val_score(DecisionTreeClassifier(),X,y,cv=10,scoring='accuracy')))
#      12
#
# NameError: name 'X' is not defined

# %% [markdown]
# #custom/domain based binning
#
# aapne knowlwgw ke hisab se binning karna cant be used using sklearn

# %% [markdown]
# #Binerization
#
# isme ham contionous value ko binay mai convert karte ho
#
# eg ; image processing

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'family'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_indexing.py in _get_column_indices(X, key)
# ...
