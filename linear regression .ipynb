# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/placement (2).csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlable('CGPA')
plt.ylaable('Package in lpa')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2197812097.py in <cell line: 0>()
#       1 plt.scatter(df['cgpa'],df['package'])
# ----> 2 plt.xlable('CGPA')
#       3 plt.ylaable('Package in lpa')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
# divide x and y

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %% [markdown]
# trian test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=2)

# %% [markdown]
# apply the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()  #creating the object of the model

# %%
lr.fit(x_train,y_train)  # fitting the data isme data train hota hai
# Out:
# LinearRegression()

# %%
lr.predict(x_test.iloc[2].values.reshape(1,1))  # predict the value
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.38464568])

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package in lpa')

#this is the linear line algo will find

# %%
m=lr.coef_  # it will find the slope of the readline

# %%
b=lr.intercept_# it will find the intercept of the red line

# %%
#y=mx+c  # this is the behind the scene how this algo works bcccc

m*8.58+b
# Out:
# array([3.89111601])

# %% [markdown]
# #linear regression from scratch without library

# %%
class lrnew:
  def __init__(self):
    self.m= None
    self.b= None

  def fit(self, x_train, y_train):
    num=0
    dem=0
    for i in range(x_train.shape[0]):
      num=num+(x_train[i]-x_train.mean())*(y_train[i]-y_train.mean())
      dem=dem+((x_train[i]-x_train.mean())*(x_train[i]-x_train.mean()))

    self.m=num/dem
    self.b=y_train.mean()-(self.m*x_train.mean())
    print(self.m)
    print(self.b)

  def predict(self, x_train):
    return self.m*x_test+self.b

# %%
df.head(1)

# %%
df=pd.read_csv("/content/placement (2).csv")
x = df.iloc[:,0].values  # Convert to numpy array
y = df.iloc[:,-1].values # Convert to numpy array

# %%
lr=lrnew()
lr.fit(x_train,y_train)

# %%
lr.predict(x_test[0])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
y_pred=lr.predict(x_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
mean_absolute_error(y_test,y_pred) #all in lpa
# Out:
# 0.2884710931878175

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.12129235313495527

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# np.float64(0.34827051717731616)

# %%
r2_score(y_test,y_predr2=)
# Out:
# 0.780730147510384

# %%
#adjusted r2 score have to appply formula

# %% [markdown]
# #multiple linear regression
