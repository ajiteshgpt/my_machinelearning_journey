# %% [markdown]
# PCA- principal component analysis, its a feature ectraction tecnique
#
# its a unsuperwized machine learning algo , ita a complex , old and quite tough
#
# pca bring the higer dimention data to the lower dimention , jiski wajaha se algorith higher  dimntion pe bhi aacha perform karega ,  jiski wajaha se uska behavior preseve rehta hai
#
# ---
#
# *benifits*
#
# 1) higer dimentional data to lower dimentional data (10d to 3d), which make fater execution of algo and computation reduce hojata ai lekin performance will remain see
#
# 2)viualization (we cant see beyong 3d , so it maked me visualize this)

# %% [markdown]
# #geometric intution
#
# variance is used to tell the spread of data , spread is directly proportional to spread..end goal is to maximixe the varience
